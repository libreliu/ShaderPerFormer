# %%
from misc.HfSpvTokenizer import HfSpvTokenizer
from misc.HfBpeTokenizer import HfBpeTokenizer
from dataset.FragmentPerformanceDataset import FragmentPerformanceDataset
import tqdm
import toyDb.ExperimentDB

# %%
dataset = FragmentPerformanceDataset(None, maxTokenizedLength=None)
toyDb.ExperimentDB.init_from_default_db()

tokenizerHF = HfSpvTokenizer(single_entrypoint=False)

# %%
spvText = dataset[166]['spvText']
print(spvText)
# Out:
# ; SPIR-V
# ; Version: 1.5
# ; Generator: Khronos Glslang Reference Front End; 11
# ; Bound: 570
# ; Schema: 0
#                OpCapability Shader
#           %1 = OpExtInstImport "GLSL.std.450"
#                OpMemoryModel Logical GLSL450
#                OpEntryPoint Fragment %main "main" %hex_codes %outColor %gl_FragCoord %_
#                OpExecutionMode %main OriginUpperLeft
#                OpSource ESSL 310
#                OpName %main "main"
#                OpName %cross2_vf2_vf2_ "cross2(vf2;vf2;"
#                OpName %p "p"
#                OpName %q "q"
#                OpName %intri_vf2_vf2_vf2_vf2_ "intri(vf2;vf2;vf2;vf2;"
#                OpName %uv "uv"
#                OpName %v1 "v1"
#                OpName %v2 "v2"
#                OpName %v3 "v3"
#                OpName %inreg_vf2_vf2_f1_f1_f1_ "inreg(vf2;vf2;f1;f1;f1;"
#                OpName %uv_0 "uv"
#                OpName %c "c"
#                OpName %n "n"
#                OpName %R "R"
#                OpName %theta "theta"
#                OpName %uv_to_hex_vf2_f1_ "uv_to_hex(vf2;f1;"
#                OpName %uv_1 "uv"
#                OpName %R_0 "R"
#                OpName %hex_display_vf2_vf2_f1_f1_f1_vf3_ "hex_display(vf2;vf2;f1;f1;f1;vf3;"
#                OpName %uv_2 "uv"
#                OpName %pos "pos"
#                OpName %chr "chr"
#                OpName %R_1 "R"
#                OpName %B "B"
#                OpName %col "col"
#                OpName %mainImage_vf4_vf2_ "mainImage(vf4;vf2;"
#                OpName %fragColor "fragColor"
#                OpName %fragCoord "fragCoord"
#                OpName %hex_codes "hex_codes"
#                OpName %outColor "outColor"
#                OpName %gl_FragCoord "gl_FragCoord"
#                OpName %param "param"
#                OpName %param_0 "param"
#                OpName %w1 "w1"
#                OpName %w2 "w2"
#                OpName %d "d"
#                OpName %s "s"
#                OpName %t "t"
#                OpName %dt "dt"
#                OpName %i "i"
#                OpName %j "j"
#                OpName %a "a"
#                OpName %b "b"
#                OpName %param_1 "param"
#                OpName %param_2 "param"
#                OpName %param_3 "param"
#                OpName %param_4 "param"
#                OpName %r "r"
#                OpName %theta_0 "theta"
#                OpName %hvec "hvec"
#                OpName %kvec "kvec"
#                OpName %b_0 "b"
#                OpName %cell "cell"
#                OpName %inhex "inhex"
#                OpName %param_5 "param"
#                OpName %param_6 "param"
#                OpName %param_7 "param"
#                OpName %param_8 "param"
#                OpName %param_9 "param"
#                OpName %param_10 "param"
#                OpName %param_11 "param"
#                OpName %r_0 "r"
#                OpName %theta_1 "theta"
#                OpName %n_0 "n"
#                OpName %i_0 "i"
#                OpName %q_0 "q"
#                OpName %ir "ir"
#                OpName %ic "ic"
#                OpName %dx "dx"
#                OpName %dy "dy"
#                OpName %param_12 "param"
#                OpName %param_13 "param"
#                OpName %param_14 "param"
#                OpName %param_15 "param"
#                OpName %param_16 "param"
#                OpName %uv_3 "uv"
#                OpName %PrimaryUBO "PrimaryUBO"
#                OpMemberName %PrimaryUBO 0 "iResolution"
#                OpMemberName %PrimaryUBO 1 "iTime"
#                OpMemberName %PrimaryUBO 2 "iChannelTime"
#                OpMemberName %PrimaryUBO 3 "iMouse"
#                OpMemberName %PrimaryUBO 4 "iDate"
#                OpMemberName %PrimaryUBO 5 "iSampleRate"
#                OpMemberName %PrimaryUBO 6 "iChannelResolution"
#                OpMemberName %PrimaryUBO 7 "iFrame"
#                OpMemberName %PrimaryUBO 8 "iTimeDelta"
#                OpMemberName %PrimaryUBO 9 "iFrameRate"
#                OpName %_ ""
#                OpName %R_2 "R"
#                OpName %r_1 "r"
#                OpName %B_0 "B"
#                OpName %hex "hex"
#                OpName %param_17 "param"
#                OpName %param_18 "param"
#                OpName %col_0 "col"
#                OpName %param_19 "param"
#                OpName %param_20 "param"
#                OpName %param_21 "param"
#                OpName %param_22 "param"
#                OpName %param_23 "param"
#                OpName %param_24 "param"
#                OpName %param_25 "param"
#                OpName %code "code"
#                OpName %param_26 "param"
#                OpName %param_27 "param"
#                OpName %param_28 "param"
#                OpName %param_29 "param"
#                OpName %param_30 "param"
#                OpName %param_31 "param"
#                OpDecorate %outColor Location 0
#                OpDecorate %gl_FragCoord BuiltIn FragCoord
#                OpDecorate %_arr_float_uint_4 ArrayStride 16
#                OpDecorate %_arr_v3float_uint_4 ArrayStride 16
#                OpMemberDecorate %PrimaryUBO 0 Offset 0
#                OpMemberDecorate %PrimaryUBO 1 Offset 12
#                OpMemberDecorate %PrimaryUBO 2 Offset 16
#                OpMemberDecorate %PrimaryUBO 3 Offset 80
#                OpMemberDecorate %PrimaryUBO 4 Offset 96
#                OpMemberDecorate %PrimaryUBO 5 Offset 112
#                OpMemberDecorate %PrimaryUBO 6 Offset 128
#                OpMemberDecorate %PrimaryUBO 7 Offset 192
#                OpMemberDecorate %PrimaryUBO 8 Offset 196
#                OpMemberDecorate %PrimaryUBO 9 Offset 200
#                OpDecorate %PrimaryUBO Block
#                OpDecorate %_ DescriptorSet 0
#                OpDecorate %_ Binding 0
#        %void = OpTypeVoid
#           %3 = OpTypeFunction %void
#       %float = OpTypeFloat 32
#     %v2float = OpTypeVector %float 2
# %_ptr_Function_v2float = OpTypePointer Function %v2float
#           %9 = OpTypeFunction %float %_ptr_Function_v2float %_ptr_Function_v2float
#        %bool = OpTypeBool
#          %15 = OpTypeFunction %bool %_ptr_Function_v2float %_ptr_Function_v2float %_ptr_Function_v2float %_ptr_Function_v2float
# %_ptr_Function_float = OpTypePointer Function %float
#          %23 = OpTypeFunction %bool %_ptr_Function_v2float %_ptr_Function_v2float %_ptr_Function_float %_ptr_Function_float %_ptr_Function_float
#          %31 = OpTypeFunction %v2float %_ptr_Function_v2float %_ptr_Function_float
#     %v3float = OpTypeVector %float 3
# %_ptr_Function_v3float = OpTypePointer Function %v3float
#          %38 = OpTypeFunction %v3float %_ptr_Function_v2float %_ptr_Function_v2float %_ptr_Function_float %_ptr_Function_float %_ptr_Function_float %_ptr_Function_v3float
#     %v4float = OpTypeVector %float 4
# %_ptr_Function_v4float = OpTypePointer Function %v4float
#          %49 = OpTypeFunction %void %_ptr_Function_v4float %_ptr_Function_v2float
#        %uint = OpTypeInt 32 0
#     %uint_49 = OpConstant %uint 49
# %_arr_float_uint_49 = OpTypeArray %float %uint_49
# %_ptr_Private__arr_float_uint_49 = OpTypePointer Private %_arr_float_uint_49
#   %hex_codes = OpVariable %_ptr_Private__arr_float_uint_49 Private
# %float_16127 = OpConstant %float 16127
# %float_12735 = OpConstant %float 12735
#  %float_9087 = OpConstant %float 9087
# %float_10681 = OpConstant %float 10681
# %float_16313 = OpConstant %float 16313
# %float_11263 = OpConstant %float 11263
# %float_19199 = OpConstant %float 19199
# %float_14719 = OpConstant %float 14719
# %float_16063 = OpConstant %float 16063
# %float_14527 = OpConstant %float 14527
# %float_12289 = OpConstant %float 12289
# %float_16145 = OpConstant %float 16145
# %float_14015 = OpConstant %float 14015
#  %float_8511 = OpConstant %float 8511
# %float_15549 = OpConstant %float 15549
# %float_14521 = OpConstant %float 14521
# %float_14777 = OpConstant %float 14777
#  %float_3839 = OpConstant %float 3839
# %float_16071 = OpConstant %float 16071
# %float_18617 = OpConstant %float 18617
# %float_13287 = OpConstant %float 13287
# %float_10687 = OpConstant %float 10687
# %float_14649 = OpConstant %float 14649
# %float_16191 = OpConstant %float 16191
# %float_14617 = OpConstant %float 14617
# %float_23709 = OpConstant %float 23709
# %float_14007 = OpConstant %float 14007
# %float_16263 = OpConstant %float 16263
# %float_10227 = OpConstant %float 10227
# %float_16255 = OpConstant %float 16255
# %float_15873 = OpConstant %float 15873
# %float_12283 = OpConstant %float 12283
# %float_16363 = OpConstant %float 16363
# %float_16015 = OpConstant %float 16015
# %float_15343 = OpConstant %float 15343
# %float_15359 = OpConstant %float 15359
# %float_15939 = OpConstant %float 15939
# %float_16383 = OpConstant %float 16383
# %float_16079 = OpConstant %float 16079
#  %float_8481 = OpConstant %float 8481
# %float_18569 = OpConstant %float 18569
# %float_16425 = OpConstant %float 16425
# %float_11777 = OpConstant %float 11777
# %float_20219 = OpConstant %float 20219
#  %float_8193 = OpConstant %float 8193
# %float_16391 = OpConstant %float 16391
# %float_17927 = OpConstant %float 17927
# %float_16767 = OpConstant %float 16767
# %float_16193 = OpConstant %float 16193
#         %108 = OpConstantComposite %_arr_float_uint_49 %float_16127 %float_12735 %float_9087 %float_10681 %float_16313 %float_11263 %float_19199 %float_14719 %float_16063 %float_14527 %float_12289 %float_16145 %float_14015 %float_8511 %float_15549 %float_14521 %float_14777 %float_3839 %float_16071 %float_18617 %float_13287 %float_10687 %float_14649 %float_16191 %float_14617 %float_23709 %float_14007 %float_16263 %float_10227 %float_16255 %float_15873 %float_12283 %float_16363 %float_16015 %float_15343 %float_15359 %float_15939 %float_16383 %float_16079 %float_8481 %float_18569 %float_16425 %float_11777 %float_20219 %float_8193 %float_16391 %float_17927 %float_16767 %float_16193
# %_ptr_Output_v4float = OpTypePointer Output %v4float
#    %outColor = OpVariable %_ptr_Output_v4float Output
# %_ptr_Input_v4float = OpTypePointer Input %v4float
# %gl_FragCoord = OpVariable %_ptr_Input_v4float Input
#      %uint_0 = OpConstant %uint 0
#      %uint_1 = OpConstant %uint 1
# %mat2v2float = OpTypeMatrix %v2float 2
#     %float_1 = OpConstant %float 1
#     %float_0 = OpConstant %float 0
#   %float_360 = OpConstant %float 360
#        %true = OpConstantTrue %bool
#       %false = OpConstantFalse %bool
# %float_0_866025388 = OpConstant %float 0.866025388
# %float_0_52359879 = OpConstant %float 0.52359879
#     %float_2 = OpConstant %float 2
#   %float_1_5 = OpConstant %float 1.5
# %_ptr_Function_mat2v2float = OpTypePointer Function %mat2v2float
# %_ptr_Function_bool = OpTypePointer Function %bool
#     %float_6 = OpConstant %float 6
#   %float_0_5 = OpConstant %float 0.5
#         %int = OpTypeInt 32 1
# %_ptr_Function_int = OpTypePointer Function %int
#       %int_0 = OpConstant %int 0
#      %int_13 = OpConstant %int 13
#    %float_n1 = OpConstant %float -1
#    %float_n2 = OpConstant %float -2
#       %int_4 = OpConstant %int 4
#       %int_8 = OpConstant %int 8
#  %float_0_75 = OpConstant %float 0.75
#         %459 = OpConstantComposite %v3float %float_0_75 %float_0_75 %float_0_75
#       %int_1 = OpConstant %int 1
#      %uint_4 = OpConstant %uint 4
# %_arr_float_uint_4 = OpTypeArray %float %uint_4
# %_arr_v3float_uint_4 = OpTypeArray %v3float %uint_4
#  %PrimaryUBO = OpTypeStruct %v3float %float %_arr_float_uint_4 %v4float %v4float %float %_arr_v3float_uint_4 %int %float %float
# %_ptr_Uniform_PrimaryUBO = OpTypePointer Uniform %PrimaryUBO
#           %_ = OpVariable %_ptr_Uniform_PrimaryUBO Uniform
# %_ptr_Uniform_float = OpTypePointer Uniform %float
# %float_0_111111112 = OpConstant %float 0.111111112
# %float_0_125 = OpConstant %float 0.125
#  %float_0_25 = OpConstant %float 0.25
#         %522 = OpConstantComposite %v3float %float_0_25 %float_0_25 %float_0_25
#     %float_4 = OpConstant %float 4
#         %531 = OpConstantComposite %v3float %float_0 %float_2 %float_4
#       %int_7 = OpConstant %int 7
# %_ptr_Uniform_int = OpTypePointer Uniform %int
#      %int_30 = OpConstant %int 30
#    %float_49 = OpConstant %float 49
# %_ptr_Private_float = OpTypePointer Private %float
#        %main = OpFunction %void None %3
#           %5 = OpLabel
#       %param = OpVariable %_ptr_Function_v4float Function
#     %param_0 = OpVariable %_ptr_Function_v2float Function
#                OpStore %hex_codes %108
#         %115 = OpLoad %v4float %gl_FragCoord
#         %116 = OpVectorShuffle %v2float %115 %115 0 1
#                OpStore %param_0 %116
#         %117 = OpFunctionCall %void %mainImage_vf4_vf2_ %param %param_0
#         %118 = OpLoad %v4float %param
#                OpStore %outColor %118
#                OpReturn
#                OpFunctionEnd
# %cross2_vf2_vf2_ = OpFunction %float None %9
#           %p = OpFunctionParameter %_ptr_Function_v2float
#           %q = OpFunctionParameter %_ptr_Function_v2float
#          %13 = OpLabel
#         %120 = OpAccessChain %_ptr_Function_float %p %uint_0
#         %121 = OpLoad %float %120
#         %123 = OpAccessChain %_ptr_Function_float %q %uint_1
#         %124 = OpLoad %float %123
#         %125 = OpFMul %float %121 %124
#         %126 = OpAccessChain %_ptr_Function_float %p %uint_1
#         %127 = OpLoad %float %126
#         %128 = OpAccessChain %_ptr_Function_float %q %uint_0
#         %129 = OpLoad %float %128
#         %130 = OpFMul %float %127 %129
#         %131 = OpFSub %float %125 %130
#                OpReturnValue %131
#                OpFunctionEnd
# %intri_vf2_vf2_vf2_vf2_ = OpFunction %bool None %15
#          %uv = OpFunctionParameter %_ptr_Function_v2float
#          %v1 = OpFunctionParameter %_ptr_Function_v2float
#          %v2 = OpFunctionParameter %_ptr_Function_v2float
#          %v3 = OpFunctionParameter %_ptr_Function_v2float
#          %21 = OpLabel
#          %w1 = OpVariable %_ptr_Function_v2float Function
#          %w2 = OpVariable %_ptr_Function_v2float Function
#           %d = OpVariable %_ptr_Function_float Function
#           %s = OpVariable %_ptr_Function_float Function
#           %t = OpVariable %_ptr_Function_float Function
#         %135 = OpLoad %v2float %v2
#         %136 = OpLoad %v2float %v1
#         %137 = OpFSub %v2float %135 %136
#                OpStore %w1 %137
#         %139 = OpLoad %v2float %v3
#         %140 = OpLoad %v2float %v1
#         %141 = OpFSub %v2float %139 %140
#                OpStore %w2 %141
#         %143 = OpLoad %v2float %w1
#         %144 = OpLoad %v2float %w2
#         %148 = OpCompositeExtract %float %143 0
#         %149 = OpCompositeExtract %float %143 1
#         %150 = OpCompositeExtract %float %144 0
#         %151 = OpCompositeExtract %float %144 1
#         %152 = OpCompositeConstruct %v2float %148 %149
#         %153 = OpCompositeConstruct %v2float %150 %151
#         %154 = OpCompositeConstruct %mat2v2float %152 %153
#         %155 = OpExtInst %float %1 Determinant %154
#                OpStore %d %155
#         %157 = OpLoad %v2float %uv
#         %158 = OpLoad %v2float %v1
#         %159 = OpFSub %v2float %157 %158
#         %160 = OpLoad %v2float %w2
#         %161 = OpCompositeExtract %float %159 0
#         %162 = OpCompositeExtract %float %159 1
#         %163 = OpCompositeExtract %float %160 0
#         %164 = OpCompositeExtract %float %160 1
#         %165 = OpCompositeConstruct %v2float %161 %162
#         %166 = OpCompositeConstruct %v2float %163 %164
#         %167 = OpCompositeConstruct %mat2v2float %165 %166
#         %168 = OpExtInst %float %1 Determinant %167
#         %169 = OpLoad %float %d
#         %170 = OpFDiv %float %168 %169
#                OpStore %s %170
#         %172 = OpLoad %v2float %w1
#         %173 = OpLoad %v2float %uv
#         %174 = OpLoad %v2float %v2
#         %175 = OpFSub %v2float %173 %174
#         %176 = OpCompositeExtract %float %172 0
#         %177 = OpCompositeExtract %float %172 1
#         %178 = OpCompositeExtract %float %175 0
#         %179 = OpCompositeExtract %float %175 1
#         %180 = OpCompositeConstruct %v2float %176 %177
#         %181 = OpCompositeConstruct %v2float %178 %179
#         %182 = OpCompositeConstruct %mat2v2float %180 %181
#         %183 = OpExtInst %float %1 Determinant %182
#         %184 = OpLoad %float %d
#         %185 = OpFDiv %float %183 %184
#                OpStore %t %185
#         %186 = OpLoad %float %s
#         %187 = OpFOrdGreaterThanEqual %bool %186 %float_0
#         %188 = OpLoad %float %t
#         %189 = OpFOrdGreaterThanEqual %bool %188 %float_0
#         %190 = OpLogicalAnd %bool %187 %189
#                OpSelectionMerge %192 None
#                OpBranchConditional %190 %191 %192
#         %191 = OpLabel
#         %193 = OpLoad %float %s
#         %194 = OpLoad %float %t
#         %195 = OpFAdd %float %193 %194
#         %196 = OpFOrdLessThanEqual %bool %195 %float_1
#                OpBranch %192
#         %192 = OpLabel
#         %197 = OpPhi %bool %190 %21 %196 %191
#                OpReturnValue %197
#                OpFunctionEnd
# %inreg_vf2_vf2_f1_f1_f1_ = OpFunction %bool None %23
#        %uv_0 = OpFunctionParameter %_ptr_Function_v2float
#           %c = OpFunctionParameter %_ptr_Function_v2float
#           %n = OpFunctionParameter %_ptr_Function_float
#           %R = OpFunctionParameter %_ptr_Function_float
#       %theta = OpFunctionParameter %_ptr_Function_float
#          %30 = OpLabel
#          %dt = OpVariable %_ptr_Function_float Function
#           %i = OpVariable %_ptr_Function_float Function
#           %j = OpVariable %_ptr_Function_float Function
#           %a = OpVariable %_ptr_Function_v2float Function
#           %b = OpVariable %_ptr_Function_v2float Function
#     %param_1 = OpVariable %_ptr_Function_v2float Function
#     %param_2 = OpVariable %_ptr_Function_v2float Function
#     %param_3 = OpVariable %_ptr_Function_v2float Function
#     %param_4 = OpVariable %_ptr_Function_v2float Function
#         %202 = OpLoad %float %n
#         %203 = OpFDiv %float %float_360 %202
#         %204 = OpExtInst %float %1 Radians %203
#                OpStore %dt %204
#                OpStore %i %float_0
#                OpStore %j %float_1
#                OpBranch %207
#         %207 = OpLabel
#                OpLoopMerge %209 %210 None
#                OpBranch %211
#         %211 = OpLabel
#         %212 = OpLoad %float %i
#         %213 = OpLoad %float %n
#         %214 = OpFOrdLessThan %bool %212 %213
#                OpBranchConditional %214 %208 %209
#         %208 = OpLabel
#         %216 = OpLoad %float %R
#         %217 = OpLoad %float %dt
#         %218 = OpLoad %float %i
#         %219 = OpFMul %float %217 %218
#         %220 = OpLoad %float %theta
#         %221 = OpFAdd %float %219 %220
#         %222 = OpExtInst %float %1 Cos %221
#         %223 = OpLoad %float %dt
#         %224 = OpLoad %float %i
#         %225 = OpFMul %float %223 %224
#         %226 = OpLoad %float %theta
#         %227 = OpFAdd %float %225 %226
#         %228 = OpExtInst %float %1 Sin %227
#         %229 = OpCompositeConstruct %v2float %222 %228
#         %230 = OpVectorTimesScalar %v2float %229 %216
#         %231 = OpLoad %v2float %c
#         %232 = OpFAdd %v2float %230 %231
#                OpStore %a %232
#         %234 = OpLoad %float %R
#         %235 = OpLoad %float %dt
#         %236 = OpLoad %float %j
#         %237 = OpFMul %float %235 %236
#         %238 = OpLoad %float %theta
#         %239 = OpFAdd %float %237 %238
#         %240 = OpExtInst %float %1 Cos %239
#         %241 = OpLoad %float %dt
#         %242 = OpLoad %float %j
#         %243 = OpFMul %float %241 %242
#         %244 = OpLoad %float %theta
#         %245 = OpFAdd %float %243 %244
#         %246 = OpExtInst %float %1 Sin %245
#         %247 = OpCompositeConstruct %v2float %240 %246
#         %248 = OpVectorTimesScalar %v2float %247 %234
#         %249 = OpLoad %v2float %c
#         %250 = OpFAdd %v2float %248 %249
#                OpStore %b %250
#         %252 = OpLoad %v2float %uv_0
#                OpStore %param_1 %252
#         %254 = OpLoad %v2float %a
#                OpStore %param_2 %254
#         %256 = OpLoad %v2float %b
#                OpStore %param_3 %256
#         %258 = OpLoad %v2float %c
#                OpStore %param_4 %258
#         %259 = OpFunctionCall %bool %intri_vf2_vf2_vf2_vf2_ %param_1 %param_2 %param_3 %param_4
#                OpSelectionMerge %261 None
#                OpBranchConditional %259 %260 %261
#         %260 = OpLabel
#                OpReturnValue %true
#         %261 = OpLabel
#                OpBranch %210
#         %210 = OpLabel
#         %264 = OpLoad %float %i
#         %265 = OpFAdd %float %264 %float_1
#                OpStore %i %265
#         %266 = OpLoad %float %j
#         %267 = OpFAdd %float %266 %float_1
#                OpStore %j %267
#                OpBranch %207
#         %209 = OpLabel
#                OpReturnValue %false
#                OpFunctionEnd
# %uv_to_hex_vf2_f1_ = OpFunction %v2float None %31
#        %uv_1 = OpFunctionParameter %_ptr_Function_v2float
#         %R_0 = OpFunctionParameter %_ptr_Function_float
#          %35 = OpLabel
#           %r = OpVariable %_ptr_Function_float Function
#     %theta_0 = OpVariable %_ptr_Function_float Function
#        %hvec = OpVariable %_ptr_Function_v2float Function
#        %kvec = OpVariable %_ptr_Function_v2float Function
#         %b_0 = OpVariable %_ptr_Function_mat2v2float Function
#        %cell = OpVariable %_ptr_Function_v2float Function
#       %inhex = OpVariable %_ptr_Function_bool Function
#     %param_5 = OpVariable %_ptr_Function_v2float Function
#     %param_6 = OpVariable %_ptr_Function_v2float Function
#     %param_7 = OpVariable %_ptr_Function_float Function
#     %param_8 = OpVariable %_ptr_Function_float Function
#     %param_9 = OpVariable %_ptr_Function_float Function
#    %param_10 = OpVariable %_ptr_Function_v2float Function
#    %param_11 = OpVariable %_ptr_Function_v2float Function
#         %344 = OpVariable %_ptr_Function_v2float Function
#         %360 = OpVariable %_ptr_Function_v2float Function
#         %272 = OpLoad %float %R_0
#         %274 = OpFMul %float %272 %float_0_866025388
#                OpStore %r %274
#                OpStore %theta_0 %float_0_52359879
#         %279 = OpLoad %float %r
#         %280 = OpFMul %float %float_2 %279
#         %281 = OpCompositeConstruct %v2float %280 %float_0
#                OpStore %hvec %281
#         %283 = OpLoad %float %r
#         %285 = OpLoad %float %R_0
#         %286 = OpFMul %float %float_1_5 %285
#         %287 = OpCompositeConstruct %v2float %283 %286
#                OpStore %kvec %287
#         %290 = OpLoad %v2float %hvec
#         %291 = OpLoad %v2float %kvec
#         %292 = OpCompositeExtract %float %290 0
#         %293 = OpCompositeExtract %float %290 1
#         %294 = OpCompositeExtract %float %291 0
#         %295 = OpCompositeExtract %float %291 1
#         %296 = OpCompositeConstruct %v2float %292 %293
#         %297 = OpCompositeConstruct %v2float %294 %295
#         %298 = OpCompositeConstruct %mat2v2float %296 %297
#                OpStore %b_0 %298
#         %300 = OpLoad %mat2v2float %b_0
#         %301 = OpLoad %mat2v2float %b_0
#         %302 = OpExtInst %mat2v2float %1 MatrixInverse %301
#         %303 = OpLoad %v2float %uv_1
#         %304 = OpMatrixTimesVector %v2float %302 %303
#         %305 = OpExtInst %v2float %1 Round %304
#         %306 = OpMatrixTimesVector %v2float %300 %305
#                OpStore %cell %306
#         %310 = OpLoad %float %theta_0
#         %311 = OpExtInst %float %1 Radians %310
#         %313 = OpLoad %v2float %uv_1
#                OpStore %param_5 %313
#         %315 = OpLoad %v2float %cell
#                OpStore %param_6 %315
#                OpStore %param_7 %float_6
#         %318 = OpLoad %float %R_0
#                OpStore %param_8 %318
#                OpStore %param_9 %311
#         %320 = OpFunctionCall %bool %inreg_vf2_vf2_f1_f1_f1_ %param_5 %param_6 %param_7 %param_8 %param_9
#                OpStore %inhex %320
#         %321 = OpLoad %bool %inhex
#         %322 = OpLogicalNot %bool %321
#                OpSelectionMerge %324 None
#                OpBranchConditional %322 %323 %324
#         %323 = OpLabel
#         %325 = OpLoad %float %r
#         %327 = OpLoad %float %R_0
#         %328 = OpFMul %float %float_0_5 %327
#         %329 = OpCompositeConstruct %v2float %325 %328
#         %330 = OpLoad %v2float %cell
#         %331 = OpLoad %v2float %uv_1
#         %332 = OpFSub %v2float %330 %331
#                OpStore %param_10 %329
#                OpStore %param_11 %332
#         %335 = OpFunctionCall %float %cross2_vf2_vf2_ %param_10 %param_11
#         %336 = OpFOrdLessThan %bool %335 %float_0
#                OpSelectionMerge %338 None
#                OpBranchConditional %336 %337 %354
#         %337 = OpLabel
#         %339 = OpAccessChain %_ptr_Function_float %uv_1 %uint_0
#         %340 = OpLoad %float %339
#         %341 = OpAccessChain %_ptr_Function_float %cell %uint_0
#         %342 = OpLoad %float %341
#         %343 = OpFOrdGreaterThan %bool %340 %342
#                OpSelectionMerge %346 None
#                OpBranchConditional %343 %345 %348
#         %345 = OpLabel
#         %347 = OpLoad %v2float %kvec
#                OpStore %344 %347
#                OpBranch %346
#         %348 = OpLabel
#         %349 = OpLoad %v2float %hvec
#         %350 = OpFNegate %v2float %349
#                OpStore %344 %350
#                OpBranch %346
#         %346 = OpLabel
#         %351 = OpLoad %v2float %344
#         %352 = OpLoad %v2float %cell
#         %353 = OpFAdd %v2float %352 %351
#                OpStore %cell %353
#                OpBranch %338
#         %354 = OpLabel
#         %355 = OpAccessChain %_ptr_Function_float %uv_1 %uint_0
#         %356 = OpLoad %float %355
#         %357 = OpAccessChain %_ptr_Function_float %cell %uint_0
#         %358 = OpLoad %float %357
#         %359 = OpFOrdGreaterThan %bool %356 %358
#                OpSelectionMerge %362 None
#                OpBranchConditional %359 %361 %364
#         %361 = OpLabel
#         %363 = OpLoad %v2float %hvec
#                OpStore %360 %363
#                OpBranch %362
#         %364 = OpLabel
#         %365 = OpLoad %v2float %kvec
#         %366 = OpFNegate %v2float %365
#                OpStore %360 %366
#                OpBranch %362
#         %362 = OpLabel
#         %367 = OpLoad %v2float %360
#         %368 = OpLoad %v2float %cell
#         %369 = OpFAdd %v2float %368 %367
#                OpStore %cell %369
#                OpBranch %338
#         %338 = OpLabel
#                OpBranch %324
#         %324 = OpLabel
#         %370 = OpLoad %v2float %cell
#                OpReturnValue %370
#                OpFunctionEnd
# %hex_display_vf2_vf2_f1_f1_f1_vf3_ = OpFunction %v3float None %38
#        %uv_2 = OpFunctionParameter %_ptr_Function_v2float
#         %pos = OpFunctionParameter %_ptr_Function_v2float
#         %chr = OpFunctionParameter %_ptr_Function_float
#         %R_1 = OpFunctionParameter %_ptr_Function_float
#           %B = OpFunctionParameter %_ptr_Function_float
#         %col = OpFunctionParameter %_ptr_Function_v3float
#          %46 = OpLabel
#         %r_0 = OpVariable %_ptr_Function_float Function
#     %theta_1 = OpVariable %_ptr_Function_float Function
#         %n_0 = OpVariable %_ptr_Function_float Function
#         %i_0 = OpVariable %_ptr_Function_int Function
#         %q_0 = OpVariable %_ptr_Function_float Function
#          %ir = OpVariable %_ptr_Function_float Function
#          %ic = OpVariable %_ptr_Function_float Function
#          %dx = OpVariable %_ptr_Function_float Function
#          %dy = OpVariable %_ptr_Function_float Function
#    %param_12 = OpVariable %_ptr_Function_v2float Function
#    %param_13 = OpVariable %_ptr_Function_v2float Function
#    %param_14 = OpVariable %_ptr_Function_float Function
#    %param_15 = OpVariable %_ptr_Function_float Function
#    %param_16 = OpVariable %_ptr_Function_float Function
#         %374 = OpLoad %float %R_1
#         %375 = OpFMul %float %374 %float_0_866025388
#                OpStore %r_0 %375
#                OpStore %theta_1 %float_0_52359879
#         %378 = OpLoad %float %chr
#                OpStore %n_0 %378
#                OpStore %i_0 %int_0
#                OpBranch %383
#         %383 = OpLabel
#                OpLoopMerge %385 %386 None
#                OpBranch %387
#         %387 = OpLabel
#         %388 = OpLoad %int %i_0
#         %390 = OpSLessThan %bool %388 %int_13
#                OpBranchConditional %390 %384 %385
#         %384 = OpLabel
#         %392 = OpLoad %float %n_0
#         %393 = OpFDiv %float %392 %float_2
#         %394 = OpExtInst %float %1 Floor %393
#                OpStore %q_0 %394
#         %395 = OpLoad %float %q_0
#         %396 = OpFMod %float %395 %float_2
#         %397 = OpFOrdEqual %bool %396 %float_1
#                OpSelectionMerge %399 None
#                OpBranchConditional %397 %398 %399
#         %398 = OpLabel
#                OpStore %ir %float_0
#                OpStore %ic %float_0
#         %402 = OpLoad %int %i_0
#                OpSelectionMerge %407 None
#                OpSwitch %402 %407 0 %403 5 %403 8 %403 1 %404 9 %404 3 %405 11 %405 4 %406 7 %406 12 %406
#         %403 = OpLabel
#                OpStore %ir %float_2
#                OpBranch %407
#         %404 = OpLabel
#                OpStore %ir %float_1
#                OpBranch %407
#         %405 = OpLabel
#                OpStore %ir %float_n1
#                OpBranch %407
#         %406 = OpLabel
#                OpStore %ir %float_n2
#                OpBranch %407
#         %407 = OpLabel
#         %415 = OpLoad %int %i_0
#         %417 = OpSLessThanEqual %bool %415 %int_4
#                OpSelectionMerge %419 None
#                OpBranchConditional %417 %418 %420
#         %418 = OpLabel
#                OpStore %ic %float_n1
#                OpBranch %419
#         %420 = OpLabel
#         %421 = OpLoad %int %i_0
#         %423 = OpSGreaterThanEqual %bool %421 %int_8
#                OpSelectionMerge %425 None
#                OpBranchConditional %423 %424 %425
#         %424 = OpLabel
#                OpStore %ic %float_1
#                OpBranch %425
#         %425 = OpLabel
#                OpBranch %419
#         %419 = OpLabel
#         %427 = OpLoad %float %ic
#         %428 = OpFMul %float %427 %float_2
#         %429 = OpLoad %float %r_0
#         %430 = OpFMul %float %428 %429
#         %431 = OpLoad %float %ir
#         %432 = OpLoad %float %r_0
#         %433 = OpFMul %float %431 %432
#         %434 = OpFAdd %float %430 %433
#                OpStore %dx %434
#         %436 = OpLoad %float %ir
#         %437 = OpFMul %float %436 %float_1_5
#         %438 = OpLoad %float %R_1
#         %439 = OpFMul %float %437 %438
#                OpStore %dy %439
#         %440 = OpLoad %v2float %pos
#         %441 = OpLoad %float %dx
#         %442 = OpLoad %float %dy
#         %443 = OpCompositeConstruct %v2float %441 %442
#         %444 = OpFAdd %v2float %440 %443
#         %445 = OpLoad %float %R_1
#         %446 = OpLoad %float %B
#         %447 = OpFSub %float %445 %446
#         %449 = OpLoad %v2float %uv_2
#                OpStore %param_12 %449
#                OpStore %param_13 %444
#                OpStore %param_14 %float_6
#                OpStore %param_15 %447
#         %454 = OpLoad %float %theta_1
#                OpStore %param_16 %454
#         %455 = OpFunctionCall %bool %inreg_vf2_vf2_f1_f1_f1_ %param_12 %param_13 %param_14 %param_15 %param_16
#                OpSelectionMerge %457 None
#                OpBranchConditional %455 %456 %457
#         %456 = OpLabel
#                OpStore %col %459
#                OpBranch %385
#         %457 = OpLabel
#                OpBranch %399
#         %399 = OpLabel
#         %461 = OpLoad %float %q_0
#                OpStore %n_0 %461
#                OpBranch %386
#         %386 = OpLabel
#         %462 = OpLoad %int %i_0
#         %464 = OpIAdd %int %462 %int_1
#                OpStore %i_0 %464
#                OpBranch %383
#         %385 = OpLabel
#         %465 = OpLoad %v3float %col
#                OpReturnValue %465
#                OpFunctionEnd
# %mainImage_vf4_vf2_ = OpFunction %void None %49
#   %fragColor = OpFunctionParameter %_ptr_Function_v4float
#   %fragCoord = OpFunctionParameter %_ptr_Function_v2float
#          %53 = OpLabel
#        %uv_3 = OpVariable %_ptr_Function_v2float Function
#         %R_2 = OpVariable %_ptr_Function_float Function
#         %r_1 = OpVariable %_ptr_Function_float Function
#         %B_0 = OpVariable %_ptr_Function_float Function
#         %hex = OpVariable %_ptr_Function_v2float Function
#    %param_17 = OpVariable %_ptr_Function_v2float Function
#    %param_18 = OpVariable %_ptr_Function_float Function
#       %col_0 = OpVariable %_ptr_Function_v3float Function
#    %param_19 = OpVariable %_ptr_Function_v2float Function
#    %param_20 = OpVariable %_ptr_Function_float Function
#    %param_21 = OpVariable %_ptr_Function_v2float Function
#    %param_22 = OpVariable %_ptr_Function_v2float Function
#    %param_23 = OpVariable %_ptr_Function_float Function
#    %param_24 = OpVariable %_ptr_Function_float Function
#    %param_25 = OpVariable %_ptr_Function_float Function
#         %518 = OpVariable %_ptr_Function_v3float Function
#        %code = OpVariable %_ptr_Function_float Function
#    %param_26 = OpVariable %_ptr_Function_v2float Function
#    %param_27 = OpVariable %_ptr_Function_v2float Function
#    %param_28 = OpVariable %_ptr_Function_float Function
#    %param_29 = OpVariable %_ptr_Function_float Function
#    %param_30 = OpVariable %_ptr_Function_float Function
#    %param_31 = OpVariable %_ptr_Function_v3float Function
#         %469 = OpLoad %v2float %fragCoord
#         %477 = OpAccessChain %_ptr_Uniform_float %_ %int_0 %uint_1
#         %478 = OpLoad %float %477
#         %479 = OpCompositeConstruct %v2float %478 %478
#         %480 = OpFDiv %v2float %469 %479
#                OpStore %uv_3 %480
#                OpStore %R_2 %float_0_111111112
#         %484 = OpLoad %float %R_2
#         %485 = OpFMul %float %484 %float_0_866025388
#                OpStore %r_1 %485
#         %487 = OpLoad %float %R_2
#         %489 = OpFMul %float %487 %float_0_125
#                OpStore %B_0 %489
#         %491 = OpAccessChain %_ptr_Uniform_float %_ %int_0 %uint_0
#         %492 = OpLoad %float %491
#         %493 = OpAccessChain %_ptr_Uniform_float %_ %int_0 %uint_1
#         %494 = OpLoad %float %493
#         %495 = OpFDiv %float %492 %494
#         %496 = OpFDiv %float %495 %float_2
#         %497 = OpCompositeConstruct %v2float %496 %float_0_5
#                OpStore %param_17 %497
#         %500 = OpLoad %float %R_2
#                OpStore %param_18 %500
#         %501 = OpFunctionCall %v2float %uv_to_hex_vf2_f1_ %param_17 %param_18
#                OpStore %hex %501
#         %504 = OpLoad %v2float %uv_3
#                OpStore %param_19 %504
#         %506 = OpLoad %float %R_2
#                OpStore %param_20 %506
#         %507 = OpFunctionCall %v2float %uv_to_hex_vf2_f1_ %param_19 %param_20
#         %508 = OpLoad %float %R_2
#         %509 = OpLoad %float %B_0
#         %510 = OpFSub %float %508 %509
#         %512 = OpLoad %v2float %uv_3
#                OpStore %param_21 %512
#                OpStore %param_22 %507
#                OpStore %param_23 %float_6
#                OpStore %param_24 %510
#                OpStore %param_25 %float_0_52359879
#         %517 = OpFunctionCall %bool %inreg_vf2_vf2_f1_f1_f1_ %param_21 %param_22 %param_23 %param_24 %param_25
#                OpSelectionMerge %520 None
#                OpBranchConditional %517 %519 %523
#         %519 = OpLabel
#                OpStore %518 %522
#                OpBranch %520
#         %523 = OpLabel
#         %524 = OpAccessChain %_ptr_Uniform_float %_ %int_1
#         %525 = OpLoad %float %524
#         %526 = OpLoad %v2float %uv_3
#         %527 = OpVectorShuffle %v3float %526 %526 0 1 0
#         %528 = OpCompositeConstruct %v3float %525 %525 %525
#         %529 = OpFAdd %v3float %528 %527
#         %532 = OpFAdd %v3float %529 %531
#         %533 = OpExtInst %v3float %1 Cos %532
#         %534 = OpVectorTimesScalar %v3float %533 %float_0_5
#         %535 = OpCompositeConstruct %v3float %float_0_5 %float_0_5 %float_0_5
#         %536 = OpFAdd %v3float %535 %534
#                OpStore %518 %536
#                OpBranch %520
#         %520 = OpLabel
#         %537 = OpLoad %v3float %518
#                OpStore %col_0 %537
#         %541 = OpAccessChain %_ptr_Uniform_int %_ %int_7
#         %542 = OpLoad %int %541
#         %544 = OpSDiv %int %542 %int_30
#         %545 = OpConvertSToF %float %544
#         %547 = OpFMod %float %545 %float_49
#         %548 = OpConvertFToS %int %547
#         %550 = OpAccessChain %_ptr_Private_float %hex_codes %548
#         %551 = OpLoad %float %550
#                OpStore %code %551
#         %553 = OpLoad %v2float %uv_3
#                OpStore %param_26 %553
#         %555 = OpLoad %v2float %hex
#                OpStore %param_27 %555
#         %557 = OpLoad %float %code
#                OpStore %param_28 %557
#         %559 = OpLoad %float %R_2
#                OpStore %param_29 %559
#         %561 = OpLoad %float %B_0
#                OpStore %param_30 %561
#         %563 = OpLoad %v3float %col_0
#                OpStore %param_31 %563
#         %564 = OpFunctionCall %v3float %hex_display_vf2_vf2_f1_f1_f1_vf3_ %param_26 %param_27 %param_28 %param_29 %param_30 %param_31
#                OpStore %col_0 %564
#         %565 = OpLoad %v3float %col_0
#         %566 = OpCompositeExtract %float %565 0
#         %567 = OpCompositeExtract %float %565 1
#         %568 = OpCompositeExtract %float %565 2
#         %569 = OpCompositeConstruct %v4float %566 %567 %568 %float_1
#                OpStore %fragColor %569
#                OpReturn
#                OpFunctionEnd

# %%
tokenizerHF(spvText)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 tokenizerHF(spvText)
#
# File ~/Projects/NGPP/venv/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:2577, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2575     if not self._in_target_context_manager:
#    2576         self._switch_to_input_mode()
# -> 2577     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    2578 if text_target is not None:
#    2579     self._switch_to_target_mode()
#
# File ~/Projects/NGPP/venv/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:2683, in PreTrainedTokenizerBase._call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2663     return self.batch_encode_plus(
#    2664         batch_text_or_text_pairs=batch_text_or_text_pairs,
#    2665         add_special_tokens=add_special_tokens,
#    (...)
#    2680         **kwargs,
#    2681     )
#    2682 else:
# -> 2683     return self.encode_plus(
#    2684         text=text,
#    2685         text_pair=text_pair,
#    2686         add_special_tokens=add_special_tokens,
#    2687         padding=padding,
#    2688         truncation=truncation,
#    2689         max_length=max_length,
#    2690         stride=stride,
#    2691         is_split_into_words=is_split_into_words,
#    2692         pad_to_multiple_of=pad_to_multiple_of,
#    2693         return_tensors=return_tensors,
#    2694         return_token_type_ids=return_token_type_ids,
#    2695         return_attention_mask=return_attention_mask,
#    2696         return_overflowing_tokens=return_overflowing_tokens,
#    2697         return_special_tokens_mask=return_special_tokens_mask,
#    2698         return_offsets_mapping=return_offsets_mapping,
#    2699         return_length=return_length,
#    2700         verbose=verbose,
#    2701         **kwargs,
#    2702     )
#
# File ~/Projects/NGPP/venv/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:2756, in PreTrainedTokenizerBase.encode_plus(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2746 # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'
#    2747 padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    2748     padding=padding,
#    2749     truncation=truncation,
#    (...)
#    2753     **kwargs,
#    2754 )
# -> 2756 return self._encode_plus(
#    2757     text=text,
#    2758     text_pair=text_pair,
#    2759     add_special_tokens=add_special_tokens,
#    2760     padding_strategy=padding_strategy,
#    2761     truncation_strategy=truncation_strategy,
#    2762     max_length=max_length,
#    2763     stride=stride,
#    2764     is_split_into_words=is_split_into_words,
#    2765     pad_to_multiple_of=pad_to_multiple_of,
#    2766     return_tensors=return_tensors,
#    2767     return_token_type_ids=return_token_type_ids,
#    2768     return_attention_mask=return_attention_mask,
#    2769     return_overflowing_tokens=return_overflowing_tokens,
#    2770     return_special_tokens_mask=return_special_tokens_mask,
#    2771     return_offsets_mapping=return_offsets_mapping,
#    2772     return_length=return_length,
#    2773     verbose=verbose,
#    2774     **kwargs,
#    2775 )
#
# File ~/Projects/NGPP/venv/lib/python3.11/site-packages/transformers/tokenization_utils.py:649, in PreTrainedTokenizer._encode_plus(self, text, text_pair, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#     640 if return_offsets_mapping:
#     641     raise NotImplementedError(
#     642         "return_offset_mapping is not available when using Python tokenizers. "
#     643         "To use this feature, change your tokenizer to one deriving from "
#    (...)
#     646         "https://github.com/huggingface/transformers/pull/2674"
#     647     )
# --> 649 first_ids = get_input_ids(text)
#     650 second_ids = get_input_ids(text_pair) if text_pair is not None else None
#     652 return self.prepare_for_model(
#     653     first_ids,
#     654     pair_ids=second_ids,
#    (...)
#     668     verbose=verbose,
#     669 )
#
# File ~/Projects/NGPP/venv/lib/python3.11/site-packages/transformers/tokenization_utils.py:616, in PreTrainedTokenizer._encode_plus.<locals>.get_input_ids(text)
#     614 def get_input_ids(text):
#     615     if isinstance(text, str):
# --> 616         tokens = self.tokenize(text, **kwargs)
#     617         return self.convert_tokens_to_ids(tokens)
#     618     elif isinstance(text, (list, tuple)) and len(text) > 0 and isinstance(text[0], str):
#
# File ~/Projects/NGPP/venv/lib/python3.11/site-packages/transformers/tokenization_utils.py:547, in PreTrainedTokenizer.tokenize(self, text, **kwargs)
#     545         tokenized_text.append(token)
#     546     else:
# --> 547         tokenized_text.extend(self._tokenize(token))
#     548 # ["This", " is", " something", "<special_token_1>", "else"]
#     549 return tokenized_text
#
# File ~/Projects/NGPP/vkPredict/misc/HfSpvTokenizer.py:87, in HfSpvTokenizer._tokenize(self, spvText, **kwargs)
#      84 assert(success)
#      86 self.tokenizer.loadSpv(self.spvProc.exportSpv())
# ---> 87 tokenizedSpv, errMsgs = self.tokenizer.tokenize()
#      88 assert(len(tokenizedSpv) > 0)
#      90 return [str(i) for i in tokenizedSpv]
#
# RuntimeError: Error while parsing referenced type of this literal in instruction
