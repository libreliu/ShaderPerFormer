# %%
import validate
import argparse

parser = argparse.ArgumentParser()
parser.add_argument('--model', type=str, default="perfformer-layer9-regression-trace-input-embedding-xformers-memeff")
parser.add_argument('--tokenizer-type', type=str, default="HfTracedSpvTokenizer-multiple-entrypoint")
parser.add_argument('--model-load-dir', type=str, default=None)
parser.add_argument('--dataset', type=str, default=None)
parser.add_argument('--target', type=str, default=None)
parser.add_argument('--batch-size', type=int, default=4)
parser.add_argument('--traced', type=bool, default=True)
args = parser.parse_args('')

# %%
dataset = [
    'FragPerfSnapshotTracedFinalDataset-UHD630-Val-TimeFiltered',
    'FragPerfSnapshotTracedFinalDataset-RX7900GRE-Val-TimeFiltered',
    'FragPerfSnapshotTracedFinalDataset-RTX4060Laptop-Val-TimeFiltered',
    'FragPerfSnapshotTracedFinalDataset-RTX3060-Val-TimeFiltered',
    'FragPerfSnapshotTracedFinalDataset-GTX1660-Val-TimeFiltered'
    ]

target = [
    '630_const',
    '7900_const',
    '4060_const',
    '3060_const',
    '1660_const'
    ]

# %%
args.traced = False

for i in range(len(dataset)):
    args.dataset = dataset[i]
    args.target = target[i]

    # validate.SHValidate(args.dataset, args.traced, args.target)
    validate.PILRValidate(args.dataset, args.traced, args.target)
# Out:
# Training: 100%|██████████| 7628/7628 [00:35<00:00, 216.36it/s, id=3tGXzW]
# model coef_=[-9.58820578e-10  2.41925591e-10 -4.22218045e-06 -6.11180440e-10
#   1.73849912e-09  1.69575287e-09 -6.73279283e-05  6.83948201e-06
#   2.40470399e-09  9.16770659e-10  8.29459168e-10  2.32830644e-10
#  -2.69210432e-10  4.72937245e-10  4.87489160e-10 -6.54836185e-10
#   3.34694050e-10 -4.22005542e-10 -2.54658516e-10  2.03726813e-10
#  -4.72937245e-10 -9.60426405e-10 -1.56433089e-10 -3.38332029e-10
#  -7.78527465e-10 -2.51020538e-10 -1.16415322e-10 -6.91215973e-11
#   1.92812877e-10 -2.25554686e-10 -5.90262061e-10  7.27595761e-12
#  -2.91038305e-11 -4.25643520e-10 -2.91038305e-11 -6.83940016e-10
#   3.67435860e-10  4.36557457e-11  1.89174898e-10 -2.47382559e-10
#   3.92901711e-10  2.03726813e-10 -3.52883944e-10 -7.27595761e-12
#  -3.56521923e-10 -2.91038305e-10 -1.28056854e-09  2.61934474e-10
#  -4.07453626e-10  6.40284270e-10 -2.91038305e-10 -1.21872290e-10
# ...

# %%
import numpy as np
from misc import metric

for tgt in target:
    preds = np.load('./validation/{}_base_preds.npy'.format(tgt))
    labels = np.load('./validation/{}_base_labels.npy'.format(tgt))

    print(f'{tgt} SH: {metric.compute_metrics(preds, labels)["mape"]: .4f}')

    preds = np.load(f'./validation/{tgt}_pilr_preds.npy')
    labels = np.load(f'./validation/{tgt}_pilr_labels.npy')

    print(f'{tgt} PILR: {metric.compute_metrics(preds, labels)["mape"]:.4f}')
# Out:
# f:\dev\NGPP\NGPP\vkPredict\misc\metric.py:39: RuntimeWarning: Mean of empty slice.
#   ((candRealTime - candPredTime)**2).mean(axis=0)
# d:\tools\conda\envs\pytorch\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# d:\tools\conda\envs\pytorch\Lib\site-packages\numpy\core\fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# 630_const SH:  0.6697
# 630_const PILR: 0.6898
# 7900_const SH:  0.6865
# 7900_const PILR: 1.0068
# 4060_const SH:  0.7954
# 4060_const PILR: 0.9849
# 3060_const SH:  0.7602
# 3060_const PILR: 0.8589
# 1660_const SH:  0.8020
# 1660_const PILR: 0.8819
